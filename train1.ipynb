# %%
# import required packages
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# Check if GPU is available
if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found. Running on CPU.")

# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all test images
train_generator = train_data_gen.flow_from_directory(
        'data/train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# Preprocess all train images
validation_generator = validation_data_gen.flow_from_directory(
        'data/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# create model structure
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

cv2.ocl.setUseOpenCL(False)

emotion_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.0001, decay=1e-6), metrics=['accuracy'])

# Train the neural network/model
emotion_model_info = emotion_model.fit(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)

# save model structure in json file
model_json = emotion_model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)

# save trained model weights in .h5 file
emotion_model.save_weights('emotion_model.h5')
# Out:
# GPU found
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Epoch 1/50
# C:\Users\deepa\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 448/448 [==============================] - 69s 142ms/step - loss: 1.8061 - accuracy: 0.2555 - val_loss: 1.7227 - val_accuracy: 0.3175
# Epoch 2/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.6358 - accuracy: 0.3640 - val_loss: 1.5367 - val_accuracy: 0.4194
# Epoch 3/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.5285 - accuracy: 0.4122 - val_loss: 1.4794 - val_accuracy: 0.4390
# Epoch 4/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.4563 - accuracy: 0.4467 - val_loss: 1.4035 - val_accuracy: 0.4693
# Epoch 5/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.3938 - accuracy: 0.4689 - val_loss: 1.3484 - val_accuracy: 0.4849
# Epoch 6/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3444 - accuracy: 0.4906 - val_loss: 1.3016 - val_accuracy: 0.5099
# Epoch 7/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.2995 - accuracy: 0.5090 - val_loss: 1.2672 - val_accuracy: 0.5173
# Epoch 8/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.2586 - accuracy: 0.5255 - val_loss: 1.2404 - val_accuracy: 0.5292
# Epoch 9/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.2216 - accuracy: 0.5394 - val_loss: 1.2269 - val_accuracy: 0.5290
# Epoch 10/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1940 - accuracy: 0.5515 - val_loss: 1.2027 - val_accuracy: 0.5469
# Epoch 11/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1629 - accuracy: 0.5659 - val_loss: 1.1876 - val_accuracy: 0.5491
# Epoch 12/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1396 - accuracy: 0.5747 - val_loss: 1.1651 - val_accuracy: 0.5615
# Epoch 13/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1137 - accuracy: 0.5829 - val_loss: 1.1468 - val_accuracy: 0.5650
# Epoch 14/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.0935 - accuracy: 0.5917 - val_loss: 1.1369 - val_accuracy: 0.5727
# Epoch 15/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0673 - accuracy: 0.5991 - val_loss: 1.1217 - val_accuracy: 0.5769
# Epoch 16/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0421 - accuracy: 0.6130 - val_loss: 1.1195 - val_accuracy: 0.5758
# Epoch 17/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.0184 - accuracy: 0.6227 - val_loss: 1.1069 - val_accuracy: 0.5861
# Epoch 18/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9968 - accuracy: 0.6320 - val_loss: 1.1034 - val_accuracy: 0.5838
# Epoch 19/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9758 - accuracy: 0.6416 - val_loss: 1.1044 - val_accuracy: 0.5827
# Epoch 20/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.9489 - accuracy: 0.6501 - val_loss: 1.0870 - val_accuracy: 0.5901
# Epoch 21/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9273 - accuracy: 0.6565 - val_loss: 1.0832 - val_accuracy: 0.5974
# Epoch 22/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9014 - accuracy: 0.6650 - val_loss: 1.0714 - val_accuracy: 0.6004
# Epoch 23/50
# 448/448 [==============================] - 11s 26ms/step - loss: 0.8809 - accuracy: 0.6751 - val_loss: 1.0747 - val_accuracy: 0.5991
# Epoch 24/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8599 - accuracy: 0.6809 - val_loss: 1.0735 - val_accuracy: 0.6006
# Epoch 25/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8387 - accuracy: 0.6935 - val_loss: 1.0627 - val_accuracy: 0.6070
# Epoch 26/50
# 448/448 [==============================] - 11s 26ms/step - loss: 0.8154 - accuracy: 0.7004 - val_loss: 1.0648 - val_accuracy: 0.6095
# Epoch 27/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7937 - accuracy: 0.7093 - val_loss: 1.0669 - val_accuracy: 0.6046
# Epoch 28/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7667 - accuracy: 0.7209 - val_loss: 1.0707 - val_accuracy: 0.6108
# Epoch 29/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.7502 - accuracy: 0.7251 - val_loss: 1.0652 - val_accuracy: 0.6045
# Epoch 30/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7217 - accuracy: 0.7352 - val_loss: 1.0823 - val_accuracy: 0.6076
# Epoch 31/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7025 - accuracy: 0.7405 - val_loss: 1.0786 - val_accuracy: 0.6141
# Epoch 32/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.6803 - accuracy: 0.7533 - val_loss: 1.0776 - val_accuracy: 0.6120
# Epoch 33/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6557 - accuracy: 0.7621 - val_loss: 1.0835 - val_accuracy: 0.6120
# Epoch 34/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6448 - accuracy: 0.7663 - val_loss: 1.1199 - val_accuracy: 0.6110
# Epoch 35/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.6231 - accuracy: 0.7742 - val_loss: 1.0818 - val_accuracy: 0.6175
# Epoch 36/50
# 448/448 [==============================] - 11s 26ms/step - loss: 0.5987 - accuracy: 0.7833 - val_loss: 1.0823 - val_accuracy: 0.6201
# Epoch 37/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5792 - accuracy: 0.7903 - val_loss: 1.1180 - val_accuracy: 0.6102
# Epoch 38/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.5633 - accuracy: 0.7956 - val_loss: 1.0927 - val_accuracy: 0.6198
# Epoch 39/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5450 - accuracy: 0.8042 - val_loss: 1.1096 - val_accuracy: 0.6187
# Epoch 40/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5350 - accuracy: 0.8059 - val_loss: 1.1246 - val_accuracy: 0.6223
# Epoch 41/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.5182 - accuracy: 0.8126 - val_loss: 1.1423 - val_accuracy: 0.6172
# Epoch 42/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4934 - accuracy: 0.8229 - val_loss: 1.1342 - val_accuracy: 0.6217
# Epoch 43/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4738 - accuracy: 0.8309 - val_loss: 1.1632 - val_accuracy: 0.6179
# Epoch 44/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4590 - accuracy: 0.8349 - val_loss: 1.1418 - val_accuracy: 0.6207
# Epoch 45/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4422 - accuracy: 0.8403 - val_loss: 1.1602 - val_accuracy: 0.6212
# Epoch 46/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4320 - accuracy: 0.8420 - val_loss: 1.1627 - val_accuracy: 0.6237
# Epoch 47/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4132 - accuracy: 0.8503 - val_loss: 1.1655 - val_accuracy: 0.6218
# Epoch 48/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4075 - accuracy: 0.8538 - val_loss: 1.1952 - val_accuracy: 0.6218
# Epoch 49/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.3987 - accuracy: 0.8559 - val_loss: 1.1959 - val_accuracy: 0.6162
# Epoch 50/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.3873 - accuracy: 0.8597 - val_loss: 1.1946 - val_accuracy: 0.6221
